# %% [markdown]
# # LangChain: Q&A over Documents
#
# An example might be a tool that would allow you to query a product catalog for items of interest.

# %%
# pip install --upgrade langchain

# %%
import os

from dotenv import load_dotenv, find_dotenv

_ = load_dotenv(find_dotenv())  # read local .env file

# %%
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import CSVLoader
from langchain.vectorstores import DocArrayInMemorySearch
from IPython.display import display, Markdown

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain.tools import tool
from langgraph.prebuilt import create_react_agent
from langchain.agents import create_agent

from dotenv import load_dotenv, find_dotenv

_ = load_dotenv(find_dotenv())  # read local .env file

import warnings

warnings.filterwarnings("ignore")

load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("DEEPSEEK_API_KEY")

llm = ChatOpenAI(
    model="deepseek-chat",
    base_url="https://api.deepseek.com/v1",
    temperature=0,
)

# %%
from langchain_community.document_loaders import CSVLoader

file = "OutdoorClothingCatalog_1000.csv"
loader = CSVLoader(file_path=file)

# %%
from langchain_classic.indexes import VectorstoreIndexCreator

# %%
# pip install docarray

# %%
from langchain_classic.vectorstores import DocArrayInMemorySearch

index = VectorstoreIndexCreator(vectorstore_cls=DocArrayInMemorySearch).from_loaders([
    loader
])

# %%
import os
from dotenv import load_dotenv, find_dotenv

# 加载 .env 中的 DEEPSEEK_API_KEY
load_dotenv(find_dotenv())

# 1. 新的导入方式 (使用 langchain_classic)
from langchain_classic.chains import RetrievalQA
from langchain_openai import ChatOpenAI
from langchain_community.document_loaders import CSVLoader
from langchain_community.vectorstores import DocArrayInMemorySearch
from langchain_classic.indexes import VectorstoreIndexCreator
from langchain_community.embeddings import HuggingFaceEmbeddings

# 2. 配置 DeepSeek 对话模型
llm = ChatOpenAI(
    model="deepseek-chat",
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url="https://api.deepseek.com",
    temperature=0,
)

# 3. 使用本地嵌入模型
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# 4. 加载 CSV 文件
file = "OutdoorClothingCatalog_1000.csv"
loader = CSVLoader(file_path=file)

# 5. 创建向量索引
index = VectorstoreIndexCreator(
    embedding=embeddings, vectorstore_cls=DocArrayInMemorySearch
).from_loaders([loader])

# 6. 执行查询
query = "Please list all your shirts with sun protection in a table in markdown and summarize each one."
response = index.query(query, llm=llm)

print(response)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File d:\anaconda\envs\ai_agent\lib\site-packages\transformers\utils\hub.py:422, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     420 if len(full_filenames) == 1:
#     421     # This is slightly better for only 1 file
# --> 422     hf_hub_download(
#     423         path_or_repo_id,
#     424         filenames[0],
#     425         subfolder=None if len(subfolder) == 0 else subfolder,
#     426         repo_type=repo_type,
#     427         revision=revision,
#     428         cache_dir=cache_dir,
#     429         user_agent=user_agent,
#     430         force_download=force_download,
#     431         proxies=proxies,
#     432         token=token,
#     433         local_files_only=local_files_only,
#     434         tqdm_class=tqdm_class,
#     435     )
#     436 else:
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\huggingface_hub\utils\_validators.py:84, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      83     if arg_name in ["repo_id", "from_id", "to_id"]:
# ---> 84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\huggingface_hub\utils\_validators.py:138, in validate_repo_id(repo_id)
#     137 if not REPO_ID_REGEX.match(repo_id):
# --> 138     raise HFValidationError(
#     139         "Repo id must use alphanumeric chars, '-', '_' or '.'."
#     140         " The name cannot start or end with '-' or '.' and the maximum length is 96:"
#     141         f" '{repo_id}'."
#     142     )
#     144 if "--" in repo_id or ".." in repo_id:
#
# HFValidationError: Repo id must use alphanumeric chars, '-', '_' or '.'. The name cannot start or end with '-' or '.' and the maximum length is 96: 'ollama/gemma4:latest'.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[23], line 28
#      18 llm = ChatOpenAI(
#      19     model="deepseek-chat",
#      20     api_key=os.getenv("DEEPSEEK_API_KEY"),
#      21     base_url="https://api.deepseek.com",
#      22     temperature=0,
#      23 )
#      25 # ------------------------------
#      26 # 2. 使用本地嵌入模型（免费，无需 API Key）
#      27 # ------------------------------
# ---> 28 embeddings = HuggingFaceEmbeddings(model_name="ollama/gemma4:latest")
#      30 # ------------------------------
#      31 # 3. 加载 CSV 文件
#      32 # ------------------------------
#      33 file = "OutdoorClothingCatalog_1000.csv"
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\langchain_core\_api\deprecation.py:258, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     256     warned = True
#     257     emit_warning()
# --> 258 return wrapped(self, *args, **kwargs)
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\langchain_community\embeddings\huggingface.py:92, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      86 except ImportError as exc:
#      87     raise ImportError(
#      88         "Could not import sentence_transformers python package. "
#      89         "Please install it with `pip install sentence-transformers`."
#      90     ) from exc
# ---> 92 self.client = sentence_transformers.SentenceTransformer(
#      93     self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#      94 )
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\sentence_transformers\util\decorators.py:41, in deprecated_kwargs.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      39         else:
#      40             kwargs.pop(old_name)
# ---> 41 return func(*args, **kwargs)
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\sentence_transformers\sentence_transformer\model.py:184, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, model_kwargs, processor_kwargs, config_kwargs, model_card_data, backend, similarity_fn_name, truncate_dim)
#     179         raise ValueError(
#     180             "Both `token` and `use_auth_token` are specified. Please only specify the `token` argument."
#     181         )
#     182     token = use_auth_token
# --> 184 super().__init__(
#     185     model_name_or_path=model_name_or_path,
#     186     modules=modules,
#     187     device=device,
#     188     cache_folder=cache_folder,
#     189     trust_remote_code=trust_remote_code,
#     190     revision=revision,
#     191     local_files_only=local_files_only,
#     192     token=token,
#     193     model_kwargs=model_kwargs,
#     194     processor_kwargs=processor_kwargs,
#     195     config_kwargs=config_kwargs,
#     196     model_card_data=model_card_data,
#     197     backend=backend,
#     198     prompts=prompts,
#     199     default_prompt_name=default_prompt_name,
#     200 )
#     201 self.model_card_data: SentenceTransformerModelCardData
#     203 # Handle INSTRUCTOR models
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\sentence_transformers\base\model.py:204, in BaseModel.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, cache_folder, trust_remote_code, revision, local_files_only, token, model_kwargs, processor_kwargs, config_kwargs, model_card_data, backend)
#     201         model_name_or_path = f"{self.default_huggingface_organization}/{model_name_or_path}"
#     203 if model_name_or_path:
# --> 204     modules, self.module_kwargs = self._load_modules(
#     205         model_name_or_path,
#     206         token=token,
#     207         cache_folder=cache_folder,
#     208         revision=revision,
#     209         trust_remote_code=trust_remote_code,
#     210         local_files_only=local_files_only,
#     211         model_kwargs=model_kwargs,
#     212         processor_kwargs=processor_kwargs,
#     213         config_kwargs=config_kwargs,
#     214     )
#     216 if modules is not None and not isinstance(modules, OrderedDict):
#     217     modules = OrderedDict([(str(idx), module) for idx, module in enumerate(modules)])
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\sentence_transformers\base\model.py:982, in BaseModel._load_modules(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, processor_kwargs, config_kwargs)
#     980 if modules_json_path is None:
#     981     logger.info(f"No modules.json found for {model_name_or_path}, initializing a new {self.model_type} model.")
# --> 982     return self._load_default_modules(model_name_or_path, **load_kwargs)
#     984 model_type_being_loaded = self._get_model_type(
#     985     model_name_or_path,
#     986     token=token,
#    (...)
#     989     local_files_only=local_files_only,
#     990 )
#     991 if model_type_being_loaded == self.model_type:
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\sentence_transformers\sentence_transformer\model.py:1062, in SentenceTransformer._load_default_modules(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, processor_kwargs, config_kwargs)
#    1059 processor_kwargs = {**shared_kwargs} if processor_kwargs is None else {**shared_kwargs, **processor_kwargs}
#    1060 config_kwargs = {**shared_kwargs} if config_kwargs is None else {**shared_kwargs, **config_kwargs}
# -> 1062 transformer_model = Transformer(
#    1063     model_name_or_path,
#    1064     cache_dir=cache_folder,
#    1065     model_kwargs=model_kwargs,
#    1066     processor_kwargs=processor_kwargs,
#    1067     config_kwargs=config_kwargs,
#    1068     backend=self.backend,
#    1069 )
#    1070 modules = [transformer_model]
#    1071 if transformer_model.module_output_name == "token_embeddings":
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\sentence_transformers\util\decorators.py:87, in transformer_kwargs_decorator.<locals>.wrapper(*args, **kwargs)
#      84             kwargs.setdefault(dict_name, {})
#      85             kwargs[dict_name].setdefault("cache_dir", cache_dir)
# ---> 87 return func(*args, **kwargs)
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\sentence_transformers\base\modules\transformer.py:630, in Transformer.__init__(self, model_name_or_path, transformer_task, model_kwargs, processor_kwargs, config_kwargs, processing_kwargs, backend, modality_config, module_output_name, unpad_inputs, max_seq_length, do_lower_case, tokenizer_name_or_path)
#     627 self._prompt_length_mapping = {}
#     628 self._method_signature_cache: dict[str, set[str]] = {}
# --> 630 config, is_peft_model = self._load_config(model_name_or_path, backend, config_kwargs)
#     631 self._warn_on_unsupported_attention_config(config)
#     633 if (
#     634     transformer_task == "sequence-classification"
#     635     and "num_labels" not in config_kwargs
#    (...)
#     641     # If we're loading a model for sequence-classification, but the base architecture is not for sequence-classification,
#     642     # and num_labels is not specified, we default to 1 label for CrossEncoder-like behavior
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\sentence_transformers\base\modules\transformer.py:1410, in Transformer._load_config(self, model_name_or_path, backend, config_kwargs)
#    1396 def _load_config(
#    1397     self, model_name_or_path: str, backend: str, config_kwargs: dict[str, Any]
#    1398 ) -> tuple[PeftConfig | PretrainedConfig, bool]:
#    1399     """Loads the transformers or PEFT configuration
#    1400
#    1401     Args:
#    (...)
#    1408         tuple[PeftConfig | PretrainedConfig, bool]: The model configuration and a boolean indicating whether the model is a PEFT model.
#    1409     """
# -> 1410     adapter_config_file = find_adapter_config_file(
#    1411         model_name_or_path,
#    1412         cache_dir=config_kwargs.get("cache_dir"),
#    1413         token=config_kwargs.get("token"),
#    1414         revision=config_kwargs.get("revision"),
#    1415         subfolder=config_kwargs.get("subfolder", ""),
#    1416         local_files_only=config_kwargs.get("local_files_only", False),
#    1417     )
#    1418     if adapter_config_file is not None:
#    1419         if backend != "torch":
#    1420             # TODO: Consider following these steps automatically so we can load PEFT models with other backends
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\transformers\utils\peft_utils.py:84, in find_adapter_config_file(model_id, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, _commit_hash)
#      82         adapter_cached_filename = os.path.join(model_id, ADAPTER_CONFIG_NAME)
#      83 else:
# ---> 84     adapter_cached_filename = cached_file(
#      85         model_id,
#      86         ADAPTER_CONFIG_NAME,
#      87         cache_dir=cache_dir,
#      88         force_download=force_download,
#      89         proxies=proxies,
#      90         token=token,
#      91         revision=revision,
#      92         local_files_only=local_files_only,
#      93         subfolder=subfolder,
#      94         _commit_hash=_commit_hash,
#      95         _raise_exceptions_for_gated_repo=False,
#      96         _raise_exceptions_for_missing_entries=False,
#      97         _raise_exceptions_for_connection_errors=False,
#      98     )
#     100 return adapter_cached_filename
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\transformers\utils\hub.py:278, in cached_file(path_or_repo_id, filename, **kwargs)
#     223 def cached_file(
#     224     path_or_repo_id: str | os.PathLike,
#     225     filename: str,
#     226     **kwargs,
#     227 ) -> str | None:
#     228     """
#     229     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     230
#    (...)
#     276     ```
#     277     """
# --> 278     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     279     file = file[0] if file is not None else file
#     280     return file
#
# File d:\anaconda\envs\ai_agent\lib\site-packages\transformers\utils\hub.py:473, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     467     raise OSError(
#     468         f"PermissionError at {e.filename} when downloading {path_or_repo_id}. "
#     469         "Check cache directory permissions. Common causes: 1) another user is downloading the same model (please wait); "
#     470         "2) a previous download was canceled and the lock file needs manual removal."
#     471     ) from e
#     472 elif isinstance(e, ValueError):
# --> 473     raise OSError(f"{e}") from e
#     475 # Now we try to recover if we can find all files correctly in the cache
#     476 resolved_files = [
#     477     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision, repo_type)
#     478     for filename in full_filenames
#     479 ]
#
# OSError: Repo id must use alphanumeric chars, '-', '_' or '.'. The name cannot start or end with '-' or '.' and the maximum length is 96: 'ollama/gemma4:latest'.

# %%
query = "Please list all your shirts with sun protection \
in a table in markdown and summarize each one."

# %%
response = index.query(query)

# %%
display(Markdown(response))

# %%
loader = CSVLoader(file_path=file)

# %%
docs = loader.load()

# %%
docs[0]

# %%
from langchain.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

# %%
embed = embeddings.embed_query("Hi my name is Harrison")

# %%
print(len(embed))

# %%
print(embed[:5])

# %%
db = DocArrayInMemorySearch.from_documents(docs, embeddings)

# %%
query = "Please suggest a shirt with sunblocking"

# %%
docs = db.similarity_search(query)

# %%
len(docs)

# %%
docs[0]

# %%
retriever = db.as_retriever()

# %%
llm = ChatOpenAI(temperature=0.0)

# %%
qdocs = "".join([docs[i].page_content for i in range(len(docs))])

# %%
response = llm.call_as_llm(
    f"{qdocs} Question: Please list all your \
shirts with sun protection in a table in markdown and summarize each one."
)

# %%
display(Markdown(response))

# %%
qa_stuff = RetrievalQA.from_chain_type(
    llm=llm, chain_type="stuff", retriever=retriever, verbose=True
)

# %%
query = "Please list all your shirts with sun protection in a table \
in markdown and summarize each one."

# %%
response = qa_stuff.run(query)

# %%
display(Markdown(response))

# %%
response = index.query(query, llm=llm)

# %%
index = VectorstoreIndexCreator(
    vectorstore_cls=DocArrayInMemorySearch,
    embedding=embeddings,
).from_loaders([loader])
